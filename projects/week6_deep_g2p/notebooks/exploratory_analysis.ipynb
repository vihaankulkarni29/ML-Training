# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn-v0_8-darkgrid')

# %%
# TODO: load a small sample from data/processed and visualize distributions
# X = np.load('../data/processed/X_train.npy', mmap_mode='r')
# y = np.load('../data/processed/y_train.npy', mmap_mode='r')
